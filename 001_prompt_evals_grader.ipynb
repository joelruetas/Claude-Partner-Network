# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name\n\nHere are several ways to extract the bucket name from an S3 URI:\n\n## Solution 1: Simple String Splitting (Python)\n```python\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Example usage\nuri = 's3://my-bucket-name/path/to/file.txt'\nbucket_name = get_s3_bucket_name(uri)\nprint(bucket_name)  # Output: my-bucket-name\n```\n\n## Solution 2: Using Regular Expressions (Python)\n```python\nimport re\n\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using regex\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Example usage\nuri = 's3://my-bucket-name/path/to/file.txt'\nbucket_name = get_s3_bucket_name(uri)\nprint(bucket_name)  # Output: my-bucket-name\n```\n\n## Solution 3: Using urllib (Python)\n```python\nfrom urllib.parse import urlparse\n\ndef get_s3_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Example usage\nuri = 's3://my-bucket-name/path/to/file.txt'\nbucket_name = get_s3_bucket_name(uri)\nprint(bucket_name)  # Output: my-bucket-name\n```\n\n## Solution 4: Bash/Shell\n```bash\n#!/bin/bash\n\ns3_uri=\"s3://my-bucket-name/path/to/file.txt\"\nbucket_name=\"${s3_uri#s3://}\"      # Remove 's3://'\nbucket_name=\"${bucket_name%%/*}\"   # Remove everything after first '/'\n\necho \"$bucket_name\"  # Output: my-bucket-name\n```\n\n## Test Cases\n```python\ntest_cases = [\n    's3://my-bucket-name/path/to/file.txt',\n    's3://bucket-123/folder/document.pdf',\n    's3://my-bucket-name/',\n    's3://bucket'\n]\n\nfor uri in test_cases:\n    print(f\"{uri} -> {get_s3_bucket_name(uri)}\")\n```\n\n**Recommended:** Use **Solution 2 (Regex)** or **Solution 3 (urllib)** for production code as they handle edge cases better.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI like 's3://my-bucket-name/path/to/file.txt' and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good breadth by offering multiple approaches, but the recommendation to use urllib (Solution 3) as a production-ready approach is problematic since urlparse doesn't correctly parse S3 URIs due to the non-standard scheme. While Solution 1 and 2 work correctly for basic cases, the lack of error handling, input validation, and mention of edge cases limits its production readiness. The regex solution (Solution 2) would actually be the most robust of the three, contrary to the recommendation."
#   },
#   {
#     "output": "# AWS IAM Role CloudFormation Template Snippet\n\nHere's a JSON CloudFormation template snippet that defines an IAM role with an assume role policy for the EC2 service:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template snippet for EC2 IAM Role\",\n  \"Resources\": {\n    \"EC2InstanceRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"RoleName\": \"EC2InstanceRole\",\n        \"Description\": \"IAM role for EC2 instances\"\n      }\n    },\n    \"EC2InstanceProfile\": {\n      \"Type\": \"AWS::IAM::InstanceProfile\",\n      \"Properties\": {\n        \"InstanceProfileName\": \"EC2InstanceProfile\",\n        \"Roles\": [\n          {\n            \"Ref\": \"EC2InstanceRole\"\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the IAM role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2InstanceRole\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"InstanceProfileArn\": {\n      \"Description\": \"ARN of the instance profile\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2InstanceProfile\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n| Component | Purpose |\n|-----------|---------|\n| **AWS::IAM::Role** | Creates the IAM role |\n| **AssumeRolePolicyDocument** | Trust policy allowing EC2 service to assume the role |\n| **Principal.Service** | `ec2.amazonaws.com` allows EC2 instances to use this role |\n| **sts:AssumeRole** | Permission for the service to assume the role |\n| **AWS::IAM::InstanceProfile** | Required to attach the role to EC2 instances |\n\n## Usage Notes:\n\n- The **InstanceProfile** is necessary when attaching this role to EC2 instances\n- You can add additional policies to this role using `AWS::IAM::RolePolicyAttachment` or `AWS::IAM::RolePolicy`\n- The `AssumeRolePolicyDocument` establishes the trust relationship with the EC2 service",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with assume role policy for EC2 service",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution is technically correct and exceeds expectations by including the InstanceProfile and outputs. The assume role policy document is properly formatted with the correct EC2 service principal. However, the interpretation of 'snippet' as a full template and lack of actual permissions reduce practical applicability. The solution demonstrates solid AWS knowledge but could be more concise and flexible for real-world scenarios."
#   },
#   {
#     "output": "# AWS Region Code to Name Mapper\n\nHere's a Python function that maps AWS region codes to their corresponding names:\n\n```python\ndef get_aws_region_name(region_code: str) -> str:\n    \"\"\"\n    Convert AWS region code to region name.\n    \n    Args:\n        region_code (str): AWS region code (e.g., 'us-east-1')\n        \n    Returns:\n        str: Region name (e.g., 'N. Virginia')\n        \n    Raises:\n        ValueError: If region code is not found\n    \"\"\"\n    aws_regions = {\n        # US Regions\n        'us-east-1': 'N. Virginia',\n        'us-east-2': 'Ohio',\n        'us-west-1': 'N. California',\n        'us-west-2': 'Oregon',\n        \n        # Europe Regions\n        'eu-west-1': 'Ireland',\n        'eu-west-2': 'London',\n        'eu-west-3': 'Paris',\n        'eu-central-1': 'Frankfurt',\n        'eu-north-1': 'Stockholm',\n        'eu-south-1': 'Milan',\n        'eu-south-2': 'Spain',\n        \n        # Asia Pacific Regions\n        'ap-southeast-1': 'Singapore',\n        'ap-southeast-2': 'Sydney',\n        'ap-northeast-1': 'Tokyo',\n        'ap-northeast-2': 'Seoul',\n        'ap-northeast-3': 'Osaka',\n        'ap-south-1': 'Mumbai',\n        'ap-east-1': 'Hong Kong',\n        \n        # Canada Region\n        'ca-central-1': 'Canada (Central)',\n        \n        # South America Region\n        'sa-east-1': 'S\u00e3o Paulo',\n        \n        # Middle East Region\n        'me-south-1': 'Bahrain',\n        'me-central-1': 'UAE',\n        \n        # Africa Region\n        'af-south-1': 'Cape Town',\n    }\n    \n    if region_code not in aws_regions:\n        raise ValueError(f\"Region code '{region_code}' not found. Valid codes: {', '.join(sorted(aws_regions.keys()))}\")\n    \n    return aws_regions[region_code]\n\n\n# Test examples\nif __name__ == \"__main__\":\n    # Test valid region codes\n    test_regions = ['us-east-1', 'eu-west-1', 'ap-southeast-1', 'us-west-2']\n    \n    for region_code in test_regions:\n        region_name = get_aws_region_name(region_code)\n        print(f\"{region_code:20} -> {region_name}\")\n    \n    print(\"\\n\" + \"=\"*50 + \"\\n\")\n    \n    # Test invalid region code\n    try:\n        get_aws_region_name('invalid-region')\n    except ValueError as e:\n        print(f\"Error: {e}\")\n```\n\n**Output:**\n```\nus-east-1           -> N. Virginia\neu-west-1           -> Ireland\nap-southeast-1      -> Singapore\nus-west-2           -> Oregon\n\n==================================================\n\nError: Region code 'invalid-region' not found. Valid codes: af-south-1, ap-east-1, ap-northeast-1, ap-northeast-2, ap-northeast-3, ap-south-1, ap-southeast-1, ap-southeast-2, ca-central-1, eu-central-1, eu-north-1, eu-south-1, eu-south-2, eu-west-1, eu-west-2, eu-west-3, me-central-1, me-south-1, sa-east-1, us-east-1, us-east-2, us-west-1, us-west-2\n```\n\n## Alternative: Using boto3 (Dynamic approach)\n\nIf you want to fetch regions dynamically from AWS:\n\n```python\nimport boto3\n\ndef get_aws_region_name_dynamic(region_code: str) -> str:\n    \"\"\"\n    ",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS region code (e.g., 'us-east-1') and returns the corresponding region name (e.g., 'N. Virginia')",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The primary solution is well-implemented with good software engineering practices. However, it has fundamental limitations for production use: it will require manual updates whenever AWS launches new regions, and the incomplete boto3 alternative suggests the solution wasn't fully developed. The static approach works perfectly for the stated task but lacks the scalability benefits mentioned in the incomplete second approach. For AWS-related code, a dynamic solution would be preferable since AWS frequently adds new regions."
#   }
# ]
