# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"s3-event-processor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-s3-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"DYNAMODB_TABLE_NAME\": \"events-table\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-bucket\",\n        \"Events\": [\"s3:ObjectCreated:*\"],\n        \"Filter\": {\n          \"Key\": {\n            \"FilterRules\": [\n              {\n                \"Name\": \"prefix\",\n                \"Value\": \"uploads/\"\n              }\n            ]\n          }\n        }\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration file for an AWS Lambda function that processes S3 events. The function should have a 30-second timeout, 256MB memory, and include environment variables for a DynamoDB table name and log level.",
#       "format": "json",
#       "solution_criteria": "Valid JSON with correct Lambda configuration structure, timeout set to 30, memory set to 256, environment variables properly defined, and valid JSON syntax"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly addresses all core requirements with valid JSON syntax, proper timeout/memory configuration, and well-structured environment variables. However, it contains placeholder values that would prevent actual deployment (ACCOUNT_ID, my-bucket) and uses SAM event syntax which may not be compatible with direct Lambda API calls or standard CloudFormation. The configuration is conceptually sound but requires minor corrections for production use."
#   },
#   {
#     "output": "\nimport json\nfrom datetime import datetime\n\ndef cloudwatch_timestamp_to_epoch(timestamp_str: str) -> int:\n    \"\"\"\n    Convert AWS CloudWatch Logs timestamp string to Unix epoch timestamp (milliseconds).\n    \n    Args:\n        timestamp_str: Timestamp in format '2024-01-15T10:30:45.123Z'\n    \n    Returns:\n        Unix epoch timestamp in milliseconds\n    \n    Raises:\n        ValueError: If timestamp format is invalid\n    \"\"\"\n    if not isinstance(timestamp_str, str):\n        raise ValueError(\"Input must be a string\")\n    \n    try:\n        # Parse the ISO 8601 format timestamp\n        dt = datetime.fromisoformat(timestamp_str.replace('Z', '+00:00'))\n        # Convert to Unix epoch in milliseconds\n        epoch_ms = int(dt.timestamp() * 1000)\n        return epoch_ms\n    except (ValueError, AttributeError) as e:\n        raise ValueError(f\"Invalid timestamp format. Expected '2024-01-15T10:30:45.123Z', got '{timestamp_str}'\") from e\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"2024-01-15T10:30:45.123Z\",\n        \"2023-12-25T00:00:00.000Z\",\n        \"2024-06-30T23:59:59.999Z\",\n    ]\n    \n    for test in test_cases:\n        try:\n            result = cloudwatch_timestamp_to_epoch(test)\n            print(json.dumps({\"input\": test, \"output\": result}))\n        except ValueError as e:\n            print(json.dumps({\"input\": test, \"error\": str(e)}))\n    \n    # Test invalid inputs\n    invalid_cases = [\"invalid\", \"2024-01-15\", None, 12345]\n    for test in invalid_cases:\n        try:\n            result = cloudwatch_timestamp_to_epoch(test)\n            print(json.dumps({\"input\": test, \"output\": result}))\n        except ValueError as e:\n            print(json.dumps({\"input\": str(test), \"error\": str(e)}))\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch Logs timestamp string in the format '2024-01-15T10:30:45.123Z' and returns the Unix epoch timestamp (milliseconds). Handle invalid input gracefully.",
#       "format": "python",
#       "solution_criteria": "Function correctly converts ISO 8601 timestamps to Unix epoch milliseconds, handles timezone conversion properly, includes error handling for invalid formats, and returns an integer"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly implements the core requirement of converting CloudWatch timestamps to Unix epoch milliseconds and handles timezone conversion properly. Error handling is robust with type checking and descriptive messages. However, there are minor issues: potential Python version compatibility concerns with fromisoformat(), an unused import, and lack of strict format validation for the milliseconds component that CloudWatch actually provides. The test coverage is good and demonstrates the function works for valid cases and gracefully fails for invalid ones."
#   },
#   {
#     "output": "\n^(?!.*--)(?!-)(?!.*-$)[a-z0-9](?:[a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regular expression that validates AWS S3 bucket names. S3 bucket names must be 3-63 characters long, contain only lowercase letters, numbers, and hyphens, start and end with a letter or number, and cannot contain consecutive hyphens.",
#       "format": "regex",
#       "solution_criteria": "Regex correctly validates bucket name length (3-63 chars), allows only lowercase letters/numbers/hyphens, ensures start/end with alphanumeric, prevents consecutive hyphens, and has minimal false positives/negatives"
#     },
#     "score": 7.5,
#     "reasoning": "The regex demonstrates strong understanding of lookaheads and most validation requirements, but contains a critical flaw: it accepts 2-character bucket names because the optional final group can match nothing. For example, 'ab' would pass validation. This needs fixing by making the middle section mandatory or adjusting quantifiers. The pattern correctly handles consecutive hyphens, start/end validation, character restrictions, and the upper length bound, but the lower bound enforcement is broken."
#   }
# ]
